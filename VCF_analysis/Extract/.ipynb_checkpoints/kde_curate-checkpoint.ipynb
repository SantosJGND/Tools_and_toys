# %%
import scipy
import numpy as np
from sklearn.neighbors import KernelDensity
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.cluster import estimate_bandwidth
from sklearn.cluster import MeanShift, estimate_bandwidth

import pandas as pd

from scipy import stats
from scipy.stats import beta
from math import sin
from random import randint

import matplotlib.pyplot as plt
import itertools as it

import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
init_notebook_mode(connected=True)

import collections

def recursively_default_dict():
        return collections.defaultdict(recursively_default_dict)

from matplotlib.collections import BrokenBarHCollection
import re

from structure_tools.Modules_tools import return_fsts

PCA_color_ref= ['darkseagreen','crimson', 'darkorange', 'darkblue', 'darkcyan',
            'darkgoldenrod', 'darkgray', 'darkgrey', 'darkgreen',
            'darkkhaki', 'darkmagenta', 'darkolivegreen', 'darkorange',
            'darkorchid', 'darkred', 'darksalmon', 'darkseagreen',
            'darkslateblue', 'darkslategray', 'darkslategrey',
            'darkturquoise', 'darkviolet', 'deeppink']
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# ### .vcf analysis
#
# Jupyter notebook for the local analysis of genetic data stored in `.vcf` format.
#
# Perform analysis of structure across data set, followed by a more detailed study of variation across local genomic windows.
#
# This particular notebook constitutes a case study of rice (*Oryza sativa*) genetic variation across a single chromosome. Data was extracted from the 3K RG data set (Mansueto *et al*. 2017) and filtered for missing data (< 0.001 % per SNP). One accession was removed for excess missing data. A subset of 15 thousand loci was then sampled randomly from chromosome 8 and converted to .vcf format (see [Upstream pre-process](https://github.com/SantosJGND/Galaxy_KDE_classifier/tree/master/Upstream_process)).
#
# ### Index:
#
# **A. Input**
#
# >i. Read vcf data and passport information of accessions within.
#
# >ii. Sample loci and accessions for a smaller data set.
#
# **B. Global structure analysis.**
#
# >i. Perform PCA and Mean Shift.
#
# >ii. Visualize structure. Decide wheather to use Mean Shift results or input classes going further.
#
# **C. Window sub-divide.**
#
# >i. Chose window size (in SNPs) and distance between windows. Windows overlap if Steps < Window_length.
#
# **D. Local cluster identification**
#
# >i. Perform mean shift clustering across windows.
#
# **E. Supervised classification.**
#
# >i. Chose reference groups, perform kernel density estimation across windows, extract p-values.
#
# >ii. Study classification patterns across windows. Alows intermediate and outlier classes.
#
# **F. Curation**
#
# >i. provide region and classification. Estimate label to cluster similarity across range provided.
#
# >ii. Plot cluster affinity against genome and physical position.
#
# >iii. Behind the scenes: PCA of genetic data at windows concerned.
#
# >iv. Propose label modification and plot new classification output.
#
#
#
#
# ### Reference
#
# - Mansueto, et al. Rice SNP-seek database update: new SNPs, indels, and queries.Nucl. Acids Res.(2017) 45 (D1): D1075-D1081. doi: 10.1093/nar/gkw1135 This paper describes new features and datasets added to SNP-Seek in 2015-2017 as well as software and database updates.

# %% [markdown]
# ### A. Input
#
# #### i. Read vcf, read passport data

# %%
from structure_tools.vcf_geno_tools import read_geno_nanum

filename= 'vcf/Extract_Chr5_15000.vcf'

row_info= 6
header_info= 9
phased= False

genotype, summary, Names= read_geno_nanum(filename, row_info= row_info, header_info= header_info,phased= phased)

print('Number of markers: {}'.format(genotype.shape[1]))
print('Number of individuals: {}'.format(genotype.shape[0]))
# Out:
# {'fileformat': 'VCFv4.2', 'fileDate': '20190327', 'source': 'PLINKv1.90', 'contig': '<ID5,length29935969>', 'INFO': '<IDPR,Number0,TypeFlag,Description"Provisional reference allele, may not be based on real reference genome">', 'FORMAT': '<IDGT,Number1,TypeString,Description"Genotype">'}
# Number of markers: 15000
# Number of individuals: 3023

# %%
## read passport information

Input_file= '3K_info.txt'

RG_info= pd.read_csv('3K_info.txt',sep= '\t')

RG_info.head()
# Out:
#   IRIS_ID                NAME   Variety_Name_verif COUNTRY REGION K9_cluster  \
# 0    B001             HEIBIAO              Heibiao   China    As6     GJ-tmp
# 1    B002           SANSUIJIN            Sansuijin   China    As6     GJ-tmp
# 2    B003         ZAOSHENGBAI        Zaoshengbai_   China    As6     GJ-adm
# 3    B004  QIUGUANGTENGXI_104  Qiuguangtengxi_104_   Japan    As7     GJ-tmp
# 4    B005              WANSHI               Wanshi   Japan    As7     GJ-tmp
#
#   Initial_subpop
# 0           temp
# 1           temp
# 2           japx
# 3           temp
# 4           temp

# %%
## Process Names vcf names.
## Instance specific processing due to ID copy in VCF file.

for x in range(len(Names)):
    ind= Names[x]
    newid= ind.split('_')
    if len(newid) > 2:
        newid= '_'.join(newid[:2])
    else:
        newid= newid[0]
    
    Names[x]= newid

# %% [markdown]
# #### ii. Subset accessions and SNPs
#
# Chose *Sn* and *Sm* for individual and marker number. Indexes will be selected randomly.
#
# *This step will allow for an input file for selection in the near future*

# %%
from structure_tools.vcf_geno_tools import geno_subset_random

Sn= 650
Sm= 13000

ID_col= 'IRIS_ID'
subset_col= 'Initial_subpop'

code= {
    'ind1A':0,
    'ind1B':0,
    'ind2':0,
    'ind3':0,
    'aus':1,
    'temp':2,
    'trop':2,
    'subtrop':2,
    'aro': 3,
    'admx': 4
}


others= 'admx'

gen_sample, subsummary, code_vec, code_lib, Nsample, Msample= geno_subset_random(genotype,
                                                                                 summary,
                                                                                 RG_info,
                                                                                 ID_col,
                                                                                 subset_col,
                                                                                 Names,
                                                                                 code= code,
                                                                                 others= others,
                                                                                 Sn= Sn, Sm= Sm)

color_groups= ['red','yellow','blue','green','purple','black','silver','silver','red3','deepskyeblue','navy','chartreuse','darkorchid3','goldenrod2']
# Out:
# gen_sample shape: 650, 13000

# %% [markdown]
# ### B. Global variation
#
# #### i. PCA
#
# Perform PCA across data set.
#
# Perform Mean shift clustering to attempt to extract genetically coherent groups of accessions.
#
# These can later be used for supervised analysis.

# %%
## Perform PCA
n_comp= 5
pca = PCA(n_components=n_comp, whiten=False,svd_solver='randomized')

feats= pca.fit_transform(gen_sample)

# %%
## perform MeanShift clustering.
bandwidth = estimate_bandwidth(feats, quantile=0.15)

ms = MeanShift(bandwidth=bandwidth, bin_seeding=False, cluster_all=True, min_bin_freq=15)
ms.fit(feats)
labels1 = ms.labels_
label_select = {y:[x for x in range(len(labels1)) if labels1[x] == y] for y in sorted(list(set(labels1)))}

# %% [markdown]
# #### ii. Structure and classification
#
# Analyse structure in data set as conveyed by PCA.

# %%
###
from structure_tools.Tutorial_subplots import plot_global_classes


plot_global_classes(feats,
                    code_lib,
                    label_select,
                    color_groups,
                    PCA_color_ref,
                    title_I= 'IRRI class',
                    title_II= 'Mean_shift',height= 900, width= 950)
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]
# [ (2,1) x3,y3 ]  [ (2,2) x4,y4 ]
# <div id="1b9fb330-694e-4b38-ae95-49cb44cfc265" style="height: 900px; width: 950px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1b9fb330-694e-4b38-ae95-49cb44cfc265", [{"marker": {"color": "red", "line": {"width": 0}, "opacity": 0.8, "size": 6, "symbol": "circle"}, "mode": "markers", "name": "0", "uid": "1b3950c0-3625-42a9-905a-a465c7056903", "x": [-9.314341027322019, -10.235392152924836, -9.728364895166788, -9.569969732263967, -10.878216211624064, -10.580255451923737, -9.218979409719578, -11.347517408524569, -8.346889043857933, -11.528700098942092, -11.686410944902898, -10.83210635757042, -8.763439312192563, -11.260844158808998, 12.909828293337899, -11.357432841231281, -10.299336878751411, -11.135801057199266, -4.786360408572637, -10.258773506500525, -9.519715727796013, -9.098413323800779, -10.082696542526639, -12.11770728827061, -12.973240974890725, -9.069386627756764, -8.827002955042488, -9.442265700774374, -8.483337097893097, -10.442485505339748, -8.758751780958024, -15.469331954656385, -7.684583375103463, -1.1882127817619983, -7.997049738434038, -1.048022807924584, -9.02299486346011, -4.609966590208449, -7.179079235603305, -12.05938391691142, -13.666978040683476, -7.72229693586062, -10.841365060598337, -9.152547606655979, 6.8254498449093814, -8.12631459177664, -8.824269749055214, -8.926420150197083, -12.041734383786071, -9.377267087047736, -10.402477142980453, -9.378541729812165, -11.383603785560625, -11.27995256648423, -11.100195472772368, -14.274710425640173, -9.163891705262433, -15.454295008430321, -14.114666530635363, -9.697752807177682, -10.435268846458625, -10.949628882645934, -10.371691405024427, -12.0155464783723, -11.250033629429806, -13.778395729414258, -11.861885780469134, -15.730947749893216, -11.260422336828949, -13.74033927512896, -1.4723508361789597, -11.79437305527565, -10.905018992240516, -14.453233300757326, -12.037569413022435, -9.646852201655298, -11.808508116251781, -13.452108757221026, -9.120650450642328, -8.401182681435182, -12.379854411116943, -9.202688780392172, -10.465216716860938, -9.40642839209013, -14.805429595443929, -11.435927712809814, -8.13624989362684, -11.604899811919319, -9.047381860683757, -14.623452260667534, 4.102912857489958, -11.512153399847822, -4.770969278471966, -9.550564775839618, -4.925324021983568, -10.001859891464242, -10.21924168506904, -11.040439867217712, -11.317626709354176, -11.525475426776332, -11.621842585044227, -10.353174050698357, -3.922597439767694, -7.426705085383763, -10.256370412603935, -9.227759420335913, -12.124915433605922, -10.154108767527093, -8.565600158470836, -14.256209590876605, -10.791254249631287, -10.807058384919218, -11.202034971917973, -11.494657005386648, -11.567926265576006, -8.611809693782659, -11.824065473230437, -9.870606811145777, -12.092066805575127, -9.264569963869665, -11.635511764671381, -16.132355747362762, -11.358302842949332, -11.407931797847468, -11.923460975227608, -11.07025519094293, -10.489999839217134, -13.490186866889392, -10.787154484914316, -13.01789646854394, -11.041702005198905, -10.551915022264799, -12.53757537570978, -16.072896199723715, -10.72004840068652, -12.863193356114321, -12.618681400067613, -11.513187592541875, -12.699180001506827, -11.139202195735669, -10.935300908579162, -11.061754525565888, -12.343618419184052, -11.256251551487411, -11.28069935633119, -9.677328078128847, -13.07960926771913, -11.417948285243929, -10.950352169106251, -11.242667680196075, -10.845411382654179, 2.882852407768502, -12.095475820391774, -13.345066248090959, -11.89130588584406, -10.429040814075579, -9.681234332820532, -9.5951813745873, -15.533105072621433, -11.413312976659617, -9.389293102467573, -11.046971971175385, -8.934984241176798, -13.043765168493978, -11.676084542883599, -12.398349291712131, -12.08317927320848, -10.425241927139561, -9.727211826955989, -13.798366090229115, -11. ...

# %% [markdown]
# ### iii. Select factor
#
# The analyses below will be informed by the distributions of groups of accessions. Chose wheather to analyse using the clustering performed here, or that provided in the input passport file.
#
# *Come back to this step to repeat analyses with a different set of labels.*

# %%
references= ['Local','External']

chose_refs= 1
ref_chosen= references[chose_refs]

if ref_chosen== 'Local':
    ref_dict= label_select
    ref_vector= labels1

if ref_chosen== 'External':
    ref_dict= code_lib
    ref_vector= code_vec

# %% [markdown]
# ### C. Window split
#
# Analyse genetic variation across genomic windows. Begin by chosing the size of each window (`window_size`) and the distance between windows (in number of markers, `Steps`).

# %%
from structure_tools.vcf_geno_tools import geno_window_split
##### 
window_size= 121
Steps= 13

Windows, Out= geno_window_split(gen_sample,
                                subsummary,
                                Steps= Steps,
                                window_size=window_size)

print('number of chromosomes: {}'.format(len(Windows)))
print('number of windows: {}'.format(sum([len(Windows[x].keys()) for x in Windows.keys()])))
# Out:
# number of chromosomes: 1
# number of windows: 992

# %% [markdown]
# ### D. MeanShift cluster analysis
#
# Parse and visualize local patterns of structure.
#
# We tackle the problem of identifying and comparing data structure across a great number of data sets.
#
# To begin, we perform mean shift and extract the respective sample *p*-values for the resulting clusters across local genomic windows.
#
#
#
#
# #### i. Cluster KDE

# %%
from structure_tools.StructE_tools import findPhiPT, Structure_profiles, Distance_profiles

from structure_tools.AMOVA_func import amova_cofactor, AMOVA_FM42
from structure_tools.mstutorial_tools import Windows_KDE_amova

### Perform Distance and association analysis on the data sets generated

### Define reference and admixed associations:
### for the purpose of this analysis exploration will be driven by
### structure distance profiles. Since KDE will be used for exploration, 
### a set of accessions can be analysed that do not contribute to 
### distance profiles.

##

ref_labels= [0,1,2]

refs_lib= {
    z: ref_dict[z] for z in ref_labels
}

KDE_comps= 4
clsize= 15
Bandwidth_split= 20


Results, Construct, PC_var= Windows_KDE_amova(Windows,
                                              ref_dict,
                                              refs_lib,
                                              supervised= True,
                                              amova= False,
                                              ncomps= KDE_comps,
                                              clsize= clsize,
                                              Bandwidth_split= Bandwidth_split)
# Out:
# going on CHR: 5

# %% [markdown]
# ### E. Supervised classification across windows.
#
# *Perform supervised classification of samples across local genomic windows using Kernel Density Estimation.*
#
# Begin by performing the KDE of selected groups across windows and extracting sample *p*-values for each.
#
# The function `KDE_windows` allows for an outlier threshold and a *p*-value comparison threshold for ambiguous classifications.
#
# KDE is run in the feature space of the PCA of local windows. Select the number of components to retain using `n_comps`.

# %%
### KDE analysis across windows
from structure_tools.Sim_ideogram_tools import Merge_class, extract_profiles, KDE_windows, KDE_window_profiles, return_ideogram

## Use result of MS classification.

ref_labels= [0,1,2]
kde_class_labels= ref_vector
n_comps= 4
Chr= 5

Windows_profiles, var_comp_store= KDE_window_profiles(Windows,ref_vector,ref_labels, Chr= Chr,n_comps= n_comps)

# %% [markdown]
# Select comparison and outlier thresholds for classification using `Comparison_threshold` and `Outlier_threshold`. Chose which groups to plot using `groups_plot`.
#
# Plot classificaiton against genotype and genomic position.

# %%
from structure_tools.Sim_ideogram_tools import compress_ideo, class_and_ideo


Comparison_threshold= 4
Outlier_threshold= 1e-5

colors= 'standard'
alt_col= PCA_color_ref

groups_plot= [0,1,2]


Blocks, ideo_kde, chromosome_list = class_and_ideo(Windows_profiles,Out,ref_vector,
                         Comparison_threshold= Comparison_threshold,
                         Outlier_threshold= Outlier_threshold,
                         groups_plot=groups_plot,
                         colors= 'standard',
                         alt_col= alt_col)

# %%
ID= 'kde_chr{}_gp{}_w{}_N{}_M{}_th{}'.format(str(Chr).zfill(2),'-'.join([str(x) for x in groups_plot]),Sn,Sm,window_size,Comparison_threshold)  

Fig_ideo= return_ideogram(ideo_kde,chromosome_list,ID,height= 30,width= 20,xticks= 1e6,xfont= 15)
# Out:
# adding ideograms...

# %% [markdown]
# ### F. Curation
#
# This is the curation step. Begin by studying the ideogram of supervised classifications above. Under the KDE approach, the proportion of intermediate classification at each locus is proportional to the degree of overlap of two or more distributions. More importantly, individual intermediate classifications indicate proximity to the region of overlap.
#
# #### *i. Target mean shift clusters using supervised classification.*
#
# We will now use these classifications to capture these shared structures. We will then force their classification to according to our judgement. This is not always a good idea. Our decision should be based on the distribution of these classifications we can observe above. In some cases a pattern of introgression from one source to another is clear. In these cases we can take the decision to classify the underlying clusters according to what we believe their true origin to be. If this sort of inference proves more complicated, then it is best to await more information to accompany a final decision.
#
# All steps should be recorded and, if presented, the reasoning behind them explained.
#
# Select target classes to use in `target_class`. Use the index of the colors of choice in the vector `color_groups` (section A).
#
# Select the range along which to query using `start` and `end`, in base pairs.
#
# The `decisions` dictionary will hold successive re-classification decisions as they are made. Run it once and after only to refresh all decisions.
#
# **Targeting**
#
# Within the range provided, every windows will be checked for the labels provided. If they are present, then mean shift and target supervised labels are compared. An accuracy measure is estimated for each cluster identified at that window using mean shift. Accuracy measures are stored in the column 'Acc' of the data frame `Coordinates`.

# %%
decisions= {}

# %%
from structure_tools.mstutorial_tools import MAC_predict

target_class= [6]

start= 26e6
end= 29e6

Coordinates = MAC_predict(Construct,
                                Blocks,
                                 Out,
                                  blocks_gp= groups_plot,
                                  label_vector= ref_vector,
                                 target_class= target_class,
                                start= start,
                                end= end)

Coordinates.head()
# Out:
# 0
# 4247
#    chrom  start     end  bl  \
# 0      5  39568  322372   0
# 1      5  39568  322372   1
# 2      5  39568  322372   2
# 3      5  39568  322372   3
# 4      5  39568  322372   4
#
#                                              members  class_6
# 0  1.5.6.12.18.23.24.27.28.30.31.32.38.39.48.57.5...      0.0
# 1  2.4.7.8.10.11.13.14.15.16.19.21.22.25.26.29.34...      0.0
# 2  3.56.70.73.75.91.95.98.107.117.120.121.122.180...      0.0
# 3  116.132.162.171.177.179.184.185.221.230.237.24...      0.0
# 4  109.163.166.250.252.310.317.336.369.370.384.39...      0.0

# %% [markdown]
# #### *ii. Plot captured haplotypes*
#
# Use the `label_threshold` on the accuracy value of each cluster to select which to plot.

# %%
from structure_tools.targeted_tools import mpl_target_ideo, chromosome_collections

select_label= target_class

label_threshold= .5

cluster_labels= [0]*Coordinates.shape[0]

for targ in target_class:
    lab= 'class_' + str(targ)
    print(max(Coordinates[lab]))
    acc= [x for x in range(Coordinates.shape[0]) if float(Coordinates[lab][x]) >= label_threshold]
    print(len(acc))
    for x in acc: 
        cluster_labels[x] = targ

Coordinates['label']= cluster_labels

plot_tool= 'mpl'

plot_who= groups_plot

order= list(it.chain(*[ref_dict[x] for x in plot_who]))
#order= list(range(len(Nsample)))
names_sample= [Names[x] for x in Nsample]
#names_sample= [names_sample[x] for x in order]

Colors= {
    -1: [192,192,192],
    1: [139,0,0],
    3: [205,0,0],
    4: [255,255,0],
    5: [255,165,0],
    6: [138,43,226],
    7: [50,205,50],
    8: [169,169,169],
    9: [255,0,0],
    2: [0,0,0]
}


if plot_tool== 'plotly':

    Colors= {
        x: 'rgba(' + ','.join([str(z) for z in Colors[x]]) + ',1)' for x in Colors.keys()
    }

    target_ideogram(select_label,Coordinates,IDs,Colors=Colors,Chr= Chr,background= False,height_chrom= .5,height= 10,width= 5)



if plot_tool== 'mpl':
    
    background= True
    ideo_height= 1
    ideo_spacing= 0
    height= 15
    width= 20
    
    xticks= 1e6
    fig_save= True
    fig_id= 'ideo_target_gp{}'.format('.'.join([str(x) for x in plot_who]))
    Home= ''

    mpl_target_ideo(select_label,
                    Coordinates,
                    names_sample,
                    order= order,
                    background= False,
                    Chr= Chr,
                    ideo_height= ideo_height,
                    ideo_spacing= ideo_spacing,
                    xticks= xticks,
                    fig_save= fig_save,
                    fig_id= 'ideo_target',
                    Colors= Colors,
                    height= height,
                    width= width,
                    Home= Home)
# Out:
# 0.7761194029850746
# 29
# 6609
# adding ideograms...

# %% [markdown]
# #### iii. Behind the scenes.
#
# Extract genetic variation at the windows concerned. Study the clusters captured.

# %%
from structure_tools.mstutorial_tools import class_structure_plot
plot_classes= target_class

## provide sample information
Name_idx= [list(RG_info[ID_col]).index(x) for x in names_sample]
code_vec= [RG_info[subset_col][x] for x in Name_idx]

Country_col= 'COUNTRY'
Country_vec= [RG_info[Country_col][x] for x in Name_idx]

Sample_info= ['<b>{}</b><br>{}, {}'.format(names_sample[x],code_vec[x],Country_vec[x]) for x in range(len(code_vec))]

class_structure_plot(Coordinates, Windows, Construct,
                     plot_classes= target_class,
                     Chr= Chr,
                        n_comp= 5,
                        height= 1000,
                        width= 900,
                        Col_vec= color_groups,
                         text= Sample_info,
                        coords= ref_dict)
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]
# [ (2,1) x3,y3 ]  [ (2,2) x4,y4 ]
# <div id="93b1e565-3ef1-4552-a151-cddf0594a425" style="height: 1000px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("93b1e565-3ef1-4552-a151-cddf0594a425", [{"marker": {"color": "red", "line": {"width": 0}, "opacity": 0.8, "size": 6, "symbol": "circle"}, "mode": "markers", "name": "0", "text": ["<b>B033</b><br>ind1B, Srilanka", "<b>B087</b><br>ind2, China", "<b>B092</b><br>ind1A, China", "<b>B104</b><br>ind1A, India", "<b>B114</b><br>ind1A, China", "<b>B115</b><br>ind1A, China", "<b>B119</b><br>ind1A, China", "<b>B127</b><br>ind1A, China", "<b>B130</b><br>ind1A, China", "<b>B150</b><br>ind1A, China", "<b>B194</b><br>ind1B, Cuba", "<b>B213</b><br>ind1A, China", "<b>B216</b><br>ind1A, China", "<b>B259</b><br>ind1A, China", "<b>CX15</b><br>ind1B, China", "<b>CX43</b><br>ind1B, Philippines", "<b>CX50</b><br>ind1B, China", "<b>CX55</b><br>ind1A, China", "<b>CX73</b><br>ind1B, Philippines", "<b>CX91</b><br>ind1B, india", "<b>CX97</b><br>ind1B, india", "<b>CX121</b><br>ind1B, China", "<b>CX131</b><br>ind1A, Myanmar", "<b>CX148</b><br>ind3, Malaysia", "<b>CX158</b><br>ind3, Vietnam", "<b>CX250</b><br>ind1B, China", "<b>CX314</b><br>ind1B, China", "<b>CX364</b><br>ind1B, 0", "<b>CX377</b><br>ind1B, Africa", "<b>CX378</b><br>ind1B, China", "<b>CX381</b><br>ind1B, 0", "<b>CX388</b><br>ind1B, Thailand", "<b>CX403</b><br>ind1B, Philippines", "<b>CX411</b><br>ind1B, nan", "<b>CX418</b><br>ind1B, nan", "<b>CX421</b><br>ind1B, nan", "<b>IRIS_313-7635</b><br>ind1B, 0", "<b>IRIS_313-7636</b><br>ind1B, Mali", "<b>IRIS_313-7650</b><br>ind2, Madagascar", "<b>IRIS_313-7691</b><br>ind1B, Philippines", "<b>IRIS_313-7725</b><br>ind2, Madagascar", "<b>IRIS_313-7816</b><br>ind1B, Senegal", "<b>IRIS_313-7820</b><br>ind1B, Senegal", "<b>IRIS_313-7824</b><br>ind1B, Senegal", "<b>IRIS_313-8067</b><br>ind1B, Italy", "<b>IRIS_313-8161</b><br>ind1B, Brazil", "<b>IRIS_313-8303</b><br>ind2, India", "<b>IRIS_313-8349</b><br>ind2, Bangladesh", "<b>IRIS_313-8557</b><br>ind3, Malaysia", "<b>IRIS_313-8608</b><br>ind3, Indonesia", "<b>IRIS_313-8616</b><br>ind1B, Philippines", "<b>IRIS_313-8643</b><br>ind3, Indonesia", "<b>IRIS_313-8702</b><br>ind3, Thailand", "<b>IRIS_313-8704</b><br>ind2, India", "<b>IRIS_313-8713</b><br>ind3, Indonesia", "<b>IRIS_313-8727</b><br>ind2, India", "<b>IRIS_313-8731</b><br>ind2, India", "<b>IRIS_313-8737</b><br>ind2, Bangladesh", "<b>IRIS_313-8744</b><br>ind3, Indonesia", "<b>IRIS_313-8796</b><br>ind2, India", "<b>IRIS_313-8812</b><br>ind3, Indonesia", "<b>IRIS_313-8831</b><br>ind3, Indonesia", "<b>IRIS_313-8854</b><br>ind2, Bangladesh", "<b>IRIS_313-8859</b><br>ind1A, China", "<b>IRIS_313-8948</b><br>ind3, Philippines", "<b>IRIS_313-8978</b><br>ind3, Indonesia", "<b>IRIS_313-8985</b><br>ind3, Thailand", "<b>IRIS_313-8996</b><br>ind3, Vietnam", "<b>IRIS_313-9006</b><br>ind3, Thailand", "<b>IRIS_313-9054</b><br>ind3, Indonesia", "<b>IRIS_313-9066</b><br>ind1B, Bangladesh", "<b>IRIS_313-9102</b><br>ind3, Malaysia", "<b>IRIS_313-9112</b><br>ind3, Thailand", "<b>IRIS_313-9148</b><br>ind2, Bangladesh", "<b>IRIS_313-9156</b><br>ind2, Bangladesh", "<b>IRIS_313-9188</b><br>ind3, Indonesia", "<b>IRIS_313-9208</b><br>ind3, Indonesia", "<b>IRIS_313-9209</b><br>ind3, Thailand", "<b>IRIS_313-9253</b><br>ind1A, China", "<b>IRIS_313-9258</b><br>ind2, India", "<b>IRIS_313-9259</b><br>ind2, India", "<b>IRIS_313-9287</b><br>ind2, India", "<b>IRIS_313-9372</b><br>ind1A, China", "<b>IRIS_313-9397</b><br>ind2, Bangladesh", "<b>IRIS_313-9403</b><br>ind2, India", "<b>IRIS_313-9461</b><br>ind3, Senegal", "<b>IRIS_313-9582</b><br>ind3, Malaysia", "<b>IRIS_313-9606</b><br>ind2, Bangladesh", "<b>IRIS_313-9706</b><br>ind1A, Taiwan", "<b>IRIS_313-9740</b><br>ind2, Madagascar", "<b>IRIS_313-9817</b><br>ind2, Netherlands", "<b>IRIS_313-9832</b><br>ind2, SriLanka", "<b>IRIS_313-9925</b><br>ind1B, SouthKo ...

# %% [markdown]
# #### iv. Decide what to change
#
# This step is important. Mostly because the current move gets stored in `decisions` and to correct it will require manual manipulation.
#
# After analysing the ideogram of targeted haplotypes together with the structure that underlies that patter, define the swhich requested for each label provided.

# %%
class_moves= {
    'moves': {
        6:0
    },
    'labs':Coordinates['label']
}

decisions[len(decisions)]= class_moves

# %%
from structure_tools.targeted_tools import renew_ideo

New_blocks, ideo_amend, chromosome_list= renew_ideo(Blocks,Coordinates,decisions,Out,ref_vector,groups_plot=groups_plot,colors= 'standard',
                  alt_col= [])
# Out:
# 11 steps provided.
# step 0, 1 moves: (8 -> 2)
# 8
# step 1, 2 moves: (6 -> 2),(8 -> 2)
# 6
# 8
# step 2, 2 moves: (6 -> 0),(8 -> 2)
# 6
# 8
# step 3, 1 moves: (5 -> 0)
# 5
# step 4, 2 moves: (5 -> 0),(6 -> 2)
# 5
# 6
# step 5, 2 moves: (5 -> 0),(7 -> 2)
# 5
# 7
# step 6, 3 moves: (6 -> 2),(7 -> 2),(8 -> 0)
# 6
# 7
# 8
# step 7, 1 moves: (5 -> 5)
# 5
# step 8, 1 moves: (5 -> 4)
# 5
# step 9, 1 moves: (6 -> 2)
# 6
# step 10, 1 moves: (6 -> 0)
# 6

# %%
ID= 'amended_chr{}_kde_gp{}_w{}_N{}_M{}_th{}'.format(str(Chr).zfill(2),'-'.join([str(x) for x in groups_plot]),Sn,Sm,window_size,Comparison_threshold)  

Fig_ideo= return_ideogram(ideo_amend,chromosome_list,ID,height= 30,width= 20,xticks= 1e6,xfont= 15)
# Out:
# adding ideograms...

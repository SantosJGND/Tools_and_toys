# %%
import scipy
import numpy as np
import pandas as pd
import itertools as it

from math import sin
import collections

def recursively_default_dict():
        return collections.defaultdict(recursively_default_dict)

from sklearn.neighbors import KernelDensity
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.preprocessing import scale

from scipy.stats.stats import pearsonr 

from scipy.stats import invgamma 
from scipy.stats import beta
import matplotlib.pyplot as plt

import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)

from IPython.display import clear_output

from Euc_pca_tools.Input_tools import read_Darwin, read_refs
from Euc_pca_tools.Euc_to_fst import Euc_to_fst
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
whil

# %% [markdown]
# ## I. Load data.
#
# The simulations performed in this post will be adjusted to the sequence length of the DataMatrix provided. We extracted SNP variation at a number of loci and stored it in DataMatrix format (Darwin software).
#
# We first load and organise our data. All the information available is in the DataMatrix file, which is useful.

# %%
## load real data

DM_filename= 'Dmatrices/RC_DataMatrix.txt'
DM_filename= 'Dmatrices/qSH1_DataMatrix.txt'
#DM_filename= 'Dmatrices/random1_DataMatrix.txt'
DM_filename= 'Dmatrices/bh4_DataMatrix.txt'
#DM_filename= 'Dmatrices/Waxy_DataMatrix.txt'
#DM_filename= 'Dmatrices/SH4_DataMatrix.txt'
#DM_filename= 'Dmatrices/Osc1_DataMatrix.txt'
#DM_filename= 'Dmatrices/Jtrop_ind3_chrom11_DataMatrix.txt'
#DM_filename= 'Dmatrices/coord_test_DataMatrix.txt'
data, Names= read_Darwin(DM_filename)
gen_data= np.array(data)

ref_file= 'Complementary_data/refs_CORE.txt' # columns: ID; code. code as preferably as integer.

if ref_file:
    ## read accession data
    ref_lib, codes= read_refs(ref_file)
    ref_names= [z for z in it.chain(*[ref_lib[r] for r in ref_lib.keys()])]
    ref_codes= np.repeat(list(ref_lib.keys()),[len(ref_lib[x]) for x in ref_lib.keys()])

    present= [x for x in range(gen_data.shape[0]) if Names[x] in ref_names] # In case some names are missing from the ref file.

    color_code= [ref_codes[ref_names.index(Names[x])] for x in present]
    color_indexes= {z:[present[x] for x in range(len(color_code)) if color_code[x] == z] for z in list(set(color_code))}
    
    ##
    colors= {
        0:[192,192,192],
        1: [255,0,0],
        2: [0,128,0],
        3: [255,255,0],
        4: [0,0,255],
        5: [255,255,255],
    }
    
    colors= {
        z: 'rgba({},.8)'.format(','.join([str(x) for x in colors[z]])) for z in colors.keys()
    }
    
    ## Currently reference codes are integers. in
    
    ref_names= ['blanc','Indica','black','cAus','Japonica','control']
    

print(gen_data.shape)
# Out:
# (947, 195)

# %% [markdown]
# ##  III. Simulations.
#
#
# The next function generates a number of data sets with a varying number of populations at varying genetic distances. For each data set euclidian distances are calculated in feature space between the centroids of the populations generated.
#
# In Summary, for each iteration, the next blocks will:
# - select population vectors from the base data set created in **I.**.
# - calculate pairwise Fsts between the selected vectors.
# - Generate a varying number of samples from each of the vectors selected.
# - perform PCA on each of the generated data sets.
# - Calculate pairwise centroid distances between the PCA projections of different haploid populations produced.
#
# First a background data set of population frequency vectors of the appropriate length is generated.
#
# - visit notebook [1 Generate Samples](https://nbviewer.jupyter.org/github/SantosJGND/Genetic-data-analysis/blob/master/Notebooks/1.%20Generating_haplotypes.ipynb) ([Stats Lab](https://github.com/SantosJGND/Stats_Lab)) for more details on the background data set.

# %%
Nbranches= 4 # number of axes
L= gen_data.shape[1] # number of markers.
n= 100 # number of frequency vectors.
n_comp_haps= 5
rangeA= [1,2.5] # range along which to vary parameter a of beta dist.
rangeB = [.1,.6] # range along which to vary parameter b of beta dist.
steps= 20 # number of steps along ranges of parameters and b.
n_comp = L # number of components to retain in PCA of frequency vectors (>>).
density= 50 # number of populations along each branch.

from Euc_pca_tools.Generate_freq_vectors import generate_Branches_Beta

features, vector_lib= generate_Branches_Beta(4,50,L,n,rangeA,rangeB,steps,n_comp
04224198345103481, 0.22058538177119077, 0.2625541437752978, 0.20211816886859585, 0.2652460624015239, 0.1552160744936204, 0.15357862820405668, 0.11331954744004757, 0.22615826628850372, 0.18134723225485894, 0.039195773243578605, 0.051395602370294606, 0.08085719587601892, 0.2991996963184838, 0.1281369402989087, 0.19459059485908906, 0.12575615371299959, 0.23643491894342167, 0.1433725660307363, 0.016345459878141844, 0.19037272720100654, 0.18609918212994822, 0.24783563648121532, 0.19214188626487372, 0.24010443393541764, 0.19007216858419135, 0.18659925713863432, 0.0014568463387118103, 0.12876093764276952, 0.1600845883929695, 0.19011348882278623, 0.2546857419750144, 0.1944836266638842, 0.14574649278935772, 0.16579083721691906, 0.20956239613127525, 0.19612914884580118, 0.1811475364129184, 0.13153670768104572, 0.16747389927321282, 0.19208447564536207, 0.2824148554506419, 0.23049424010668768, 0.1985331327553459, 0.005053946711174112, 0.18846032353485595, 0.2625017278969219, 0.01752763388613143, 0.2102303546686518, 0.19946744084798795, 0.294117040678177, 0.17646936349978345, 0.16915050047745947,  ...

# %% [markdown]
# **Fig. True and predicted Fsts.**

# %% [markdown]
# ### Fst and euclidian genetic distances

# %% [markdown]
# ## Real data
#
# In this section we apply the relation learned during the preceding simulation step to the study of genetic structure at the chosen locus.
#
# i. We will first perform PCA on the data matrix loaded, together with haplotypes from the two control populations. The data matrix came with labels and individual IDs. These are displayed in the first graph.
#
# ii. We then perform Mean Shift unsupervised clustering to the real data in feature space. MeanShift is a clustering algorithm that relies on the KDE estimate of observed data to identify peaks, to which it assigns observations based on proximity ( ** ). The output of this clusterisation is displayed on the second graph.
#
# iii. For the third part the user is first asked to chose a set of MeanShift clusters. The pairwise distances between the centroids of the chosen clusters will be calculated and their respective Fsts inferred from the relation shown in the above plot. The clusters chosen and the vectors connecting are plotted, annotated with their respective distances.

# %%
### Build control data set with apropriate distances.
from Euc_pca_tools.plot_tools import plot_3D
diploid= True

length_haps= gen_data.shape[1]

## Perform PCA with or without including control populations.
gen_data= np.nan_to_num(gen_data)

pca = PCA(n_components=3, whiten=False,svd_solver='randomized').fit(gen_data)
feats= pca.transform(gen_data)
var_comps= pca.explained_variance_ratio_

if ref_file:
     
    plot_3D(feats,color_indexes,colors= colors,Names=Names,var_comps= var_comps,ref_names= ref_names)
# Out:
# c:\users\jgarcia\appdata\local\programs\python\python36-32\lib\site-packages\plotly\graph_objs\_deprecations.py:477: DeprecationWarning:
#
# plotly.graph_objs.Scene is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.Scene
# <div id="f019cba3-b671-4169-8659-12e460147f4b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f019cba3-b671-4169-8659-12e460147f4b", [{"marker": {"color": "rgba(255,0,0,.8)", "line": {"width": 0}, "opacity": 1, "size": 4, "symbol": "circle"}, "mode": "markers", "name": "Indica", "text": ["ID: IRIS_313-9121, gp: Indica", "ID: IRIS_313-11162, gp: Indica", "ID: B010, gp: Indica", "ID: IRIS_313-9182, gp: Indica", "ID: IRIS_313-10990, gp: Indica", "ID: B026, gp: Indica", "ID: B029, gp: Indica", "ID: IRIS_313-10511, gp: Indica", "ID: IRIS_313-11205, gp: Indica", "ID: IRIS_313-9262, gp: Indica", "ID: IRIS_313-8660, gp: Indica", "ID: B059, gp: Indica", "ID: B061, gp: Indica", "ID: IRIS_313-9317, gp: Indica", "ID: IRIS_313-9320, gp: Indica", "ID: IRIS_313-9324, gp: Indica", "ID: IRIS_313-9325, gp: Indica", "ID: IRIS_313-10997, gp: Indica", "ID: IRIS_313-10614, gp: Indica", "ID: B073, gp: Indica", "ID: IRIS_313-11234, gp: Indica", "ID: B076, gp: Indica", "ID: B079, gp: Indica", "ID: B081, gp: Indica", "ID: IRIS_313-9384, gp: Indica", "ID: B089, gp: Indica", "ID: B090, gp: Indica", "ID: B091, gp: Indica", "ID: B092, gp: Indica", "ID: B094, gp: Indica", "ID: B095, gp: Indica", "ID: B096, gp: Indica", "ID: B097, gp: Indica", "ID: IRIS_313-11256, gp: Indica", "ID: IRIS_313-9424, gp: Indica", "ID: IRIS_313-9427, gp: Indica", "ID: IRIS_313-11261, gp: Indica", "ID: IRIS_313-11262, gp: Indica", "ID: B107, gp: Indica", "ID: IRIS_313-11264, gp: Indica", "ID: IRIS_313-11266, gp: Indica", "ID: IRIS_313-11267, gp: Indica", "ID: B113, gp: Indica", "ID: B115, gp: Indica", "ID: B116, gp: Indica", "ID: IRIS_313-11273, gp: Indica", "ID: IRIS_313-11275, gp: Indica", "ID: IRIS_313-11276, gp: Indica", "ID: B121, gp: Indica", "ID: IRIS_313-9492, gp: Indica", "ID: B123, gp: Indica", "ID: IRIS_313-11280, gp: Indica", "ID: B125, gp: Indica", "ID: IRIS_313-11282, gp: Indica", "ID: IRIS_313-11283, gp: Indica", "ID: IRIS_313-11284, gp: Indica", "ID: B129, gp: Indica", "ID: B130, gp: Indica", "ID: B131, gp: Indica", "ID: IRIS_313-11288, gp: Indica", "ID: IRIS_313-11292, gp: Indica", "ID: IRIS_313-11294, gp: Indica", "ID: IRIS_313-9560, gp: Indica", "ID: B140, gp: Indica", "ID: IRIS_313-9570, gp: Indica", "ID: IRIS_313-11300, gp: Indica", "ID: IRIS_313-11301, gp: Indica", "ID: IRIS_313-11303, gp: Indica", "ID: IRIS_313-9590, gp: Indica", "ID: B149, gp: Indica", "ID: IRIS_313-9594, gp: Indica", "ID: IRIS_313-11307, gp: Indica", "ID: IRIS_313-11308, gp: Indica", "ID: IRIS_313-11309, gp: Indica", "ID: IRIS_313-11310, gp: Indica", "ID: IRIS_313-9605, gp: Indica", "ID: B157, gp: Indica", "ID: IRIS_313-11316, gp: Indica", "ID: IRIS_313-9619, gp: Indica", "ID: B163, gp: Indica", "ID: IRIS_313-11321, gp: Indica", "ID: IRIS_313-9634, gp: Indica", "ID: IRIS_313-11338, gp: Indica", "ID: IRIS_313-11345, gp: Indica", "ID: IRIS_313-11346, gp: Indica", "ID: IRIS_313-11347, gp: Indica", "ID: B197, gp: Indica", "ID: IRIS_313-10814, gp: Indica", "ID: B208, gp: Indica", "ID: B210, gp: Indica", "ID: B214, gp: Indica", "ID: B216, gp: Indica", "ID: B217, gp: Indica", "ID: B222, gp: Indica", "ID: IRIS_313-10847, gp: Indica", "ID: IRIS_313-11306, gp: Indica", "ID: B229, gp: Indica", "ID: IRIS_313-11382, gp: Indica", "ID: IRIS_313-11383, gp: Indica", "ID: IRIS_313-11386, gp: Indica", "ID: IRIS_313-9867, gp: Indica", "ID: B247, gp: Indica", "ID: B249, gp: Indica", "ID: B252, gp: Indica", "ID: B253, gp: Indica", "ID: B254, gp: Indica", "ID: B259, gp: Indica", "ID: IRIS_313-11407, gp: Indica", "ID: B264, gp: Indica", "ID: B265, gp: Indica", "ID: IRIS_313-9968, gp: Indica", "ID: IRIS_313-9969, gp: Indica", "ID: IRIS_313-11206, gp: Indica", "ID: IRIS_313-9976, gp: Indica", "ID: IRIS_313-10674, gp: Indica", "ID: IRIS_313-11442, gp: Indica", "ID: IRIS_313-10675, gp: Indica", "ID: IRIS_313-11447, gp: Indica", "I ...

# %% [markdown]
# **Fig. Genetic structure** at locus of choice.

# %%
#### MeanShift clusters

N= 50
bandwidth = estimate_bandwidth(feats, quantile=0.1)
params = {'bandwidth': np.linspace(np.min(feats), np.max(feats),20)}
grid = GridSearchCV(KernelDensity(algorithm = "ball_tree",breadth_first = False), params,verbose=0)

## perform MeanShift clustering.
ms = MeanShift(bandwidth=bandwidth, bin_seeding=False, cluster_all=True, min_bin_freq=25)
ms.fit(feats[present,:])
labels1 = ms.labels_
label_select = {y:[present[x] for x in range(len(labels1)) if labels1[x] == y] for y in sorted(list(set(labels1))) if y != -1}

iu_control= np.triu_indices(len(label_select),1)
MS_centroids= [np.mean(feats[label_select[z],:],axis= 0) for z in label_select.keys()]
MS_pair_dist= pairwise_distances(MS_centroids,metric= 'euclidean')
MS_pair_dist= MS_pair_dist[iu_control]

plot_3D(feats,label_select,Names=Names,var_comps= var_comps)
# Out:
# c:\users\jgarcia\appdata\local\programs\python\python36-32\lib\site-packages\plotly\graph_objs\_deprecations.py:477: DeprecationWarning:
#
# plotly.graph_objs.Scene is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.Scene
# <div id="d5008b82-5454-4d00-b1b6-c6bedcc7b11b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d5008b82-5454-4d00-b1b6-c6bedcc7b11b", [{"marker": {"color": 0, "line": {"width": 0}, "opacity": 1, "size": 4, "symbol": "circle"}, "mode": "markers", "name": "0", "text": ["ID: IRIS_313-10990, gp: 0", "ID: IRIS_313-8660, gp: 0", "ID: IRIS_313-9317, gp: 0", "ID: IRIS_313-9320, gp: 0", "ID: IRIS_313-9325, gp: 0", "ID: IRIS_313-10997, gp: 0", "ID: IRIS_313-10614, gp: 0", "ID: B076, gp: 0", "ID: B081, gp: 0", "ID: B090, gp: 0", "ID: B094, gp: 0", "ID: B095, gp: 0", "ID: IRIS_313-11256, gp: 0", "ID: IRIS_313-9424, gp: 0", "ID: IRIS_313-9427, gp: 0", "ID: IRIS_313-11261, gp: 0", "ID: B107, gp: 0", "ID: IRIS_313-11264, gp: 0", "ID: IRIS_313-11273, gp: 0", "ID: IRIS_313-11275, gp: 0", "ID: IRIS_313-11276, gp: 0", "ID: IRIS_313-11280, gp: 0", "ID: IRIS_313-11283, gp: 0", "ID: IRIS_313-11284, gp: 0", "ID: B129, gp: 0", "ID: B130, gp: 0", "ID: IRIS_313-11288, gp: 0", "ID: IRIS_313-11292, gp: 0", "ID: IRIS_313-11294, gp: 0", "ID: IRIS_313-9560, gp: 0", "ID: IRIS_313-11301, gp: 0", "ID: IRIS_313-11303, gp: 0", "ID: IRIS_313-9590, gp: 0", "ID: IRIS_313-11307, gp: 0", "ID: IRIS_313-11309, gp: 0", "ID: IRIS_313-11316, gp: 0", "ID: IRIS_313-9619, gp: 0", "ID: IRIS_313-11321, gp: 0", "ID: IRIS_313-9634, gp: 0", "ID: IRIS_313-11338, gp: 0", "ID: IRIS_313-11345, gp: 0", "ID: IRIS_313-11346, gp: 0", "ID: IRIS_313-11347, gp: 0", "ID: IRIS_313-10814, gp: 0", "ID: B214, gp: 0", "ID: B216, gp: 0", "ID: IRIS_313-10847, g
# %% [markdown]
# **Fig. Mean Shift clustering of PCA projections** of real data at locus of choice.
#
# Identify accessions at MS cluster of choice.

# %% [markdown]
# At the top of the next block, select the clusters between which to calculate distances.

# %%
from Euc_pca_tools.plot_tools import plot_vertix
#### Making it interesting:
Vertices= [0,1,2,10]

plot_vertix(feats,label_select,Vertices,m_coeff= m_coeff,b= b, color= '#1f77b4')
# Out:
# c:\users\jgarcia\appdata\local\programs\python\python36-32\lib\site-packages\plotly\graph_objs\_deprecations.py:477: DeprecationWarning:
#
# plotly.graph_objs.Scene is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.Scene
# <div id="5ce3bcf1-582e-4623-9528-b8a22b033344" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("5ce3bcf1-582e-4623-9528-b8a22b033344", [{"line": {"color": 0, "width": 2}, "marker": {"color": "#1f77b4", "size": 5}, "name": "pred Fst (0, 1): 0.01", "text": ["group: 0", "group: 1"], "x": [-0.7242545959453912, -0.7719284229484739], "y": [-0.08425751319562749, -0.13971728320267682], "z": [-0.38096153644602104, 1.6017159214066545], "type": "scatter3d", "uid": "f2090d10-8acd-4aff-8ce5-181f0965b2bd"}, {"line": {"color": 1, "width": 2}, "marker": {"color": "#1f77b4", "size": 5}, "name": "pred Fst (0, 2): 0.34", "text": ["group: 0", "group: 2"], "x": [-0.7242545959453912, 15.165164639681958], "y": [-0.08425751319562749, -1.3071210413357655], "z": [-0.38096153644602104, 0.03206777504022622], "type": "scatter3d", "uid": "1e8ac603-b3d6-45d0-92a3-d27e5f2bb80c"}, {"line": {"color": 2, "width": 2}, "marker": {"color": "#1f77b4", "size": 5}, "name": "pred Fst (0, 10): 0.23", "text": ["group: 0", "group: 10"], "x": [-0.7242545959453912, 5.05228351266294], "y": [-0.08425751319562749, 10.86721064717024], "z": [-0.38096153644602104, 0.14918196398869507], "type": "scatter3d", "uid": "1e583ee3-a38a-478f-a2d7-4e8eb206253a"}, {"line": {"color": 3, "width": 2}, "marker": {"color": "#1f77b4", "size": 5}, "name": "pred Fst (1, 2): 0.35", "text": ["group: 1", "group: 2"], "x": [-0.7719284229484739, 15.165164639681958], "y": [-0.13971728320267682, -1.3071210413357655], "z": [1.6017159214066545, 0.03206777504022622], "type": "scatter3d", "uid": "8e969ce8-5c00-4c3e-ae24-e3fce3fc3403"}, {"line": {"color": 4, "width": 2}, "marker": {"color": "#1f77b4", "size": 5}, "name": "pred Fst (1, 10): 0.23", "text": ["group: 1", "group: 10"], "x": [-0.7719284229484739, 5.05228351266294], "y": [-0.13971728320267682, 10.86721064717024], "z": [1.6017159214066545, 0.14918196398869507], "type": "scatter3d", "uid": "2d5fc65a-7c17-4110-86eb-56ac447e4365"}, {"line": {"color": 5, "width": 2}, "marker": {"color": "#1f77b4", "size": 5}, "name": "pred Fst (2, 10): 0.34", "text": ["group: 2", "group: 10"], "x": [15.165164639681958, 5.05228351266294], "y": [-1.3071210413357655, 10.86721064717024], "z": [0.03206777504022622, 0.14918196398869507], "type": "scatter3d", "uid": "91bf40c5-ee3b-415b-89b0-d95d62e2322a"}, {"marker": {"color": "#1f77b4", "size": 5}, "mode": "markers", "name": "Cl: 0", "x": [-0.7227024372794716, -0.7230059815633162, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.72330978093928, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.724527535806373, -0.7227024372794716, -0.7236138357290589, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.724527535806373, -0.7227024372794716, -0.7227024372794716, -0.724527535806373, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7236138357290589, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.724527535806373, -0.7227024372794716, -0.7227024372794716, -0.7254436746486995, -0.7236139634896728, -0.7230059815633162, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7230059815633162, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.7227024372794716, -0.724527535806373, -0.7227024372794716, -0.7227024372794716, -0.7233097809392799, -0.7227024372794716, -0.729741 ...

# %% [markdown]
# **Fig. Genetic structure summary** Genetic distances between clusters selected are represented as edges.

# %%
import scipy
import numpy as np
import pandas as pd
import itertools as it

from math import sin
import collections

def recursively_default_dict():
        return collections.defaultdict(recursively_default_dict)

from sklearn.neighbors import KernelDensity
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.cluster import MeanShift, estimate_bandwidth
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.preprocessing import scale

from scipy.stats.stats import pearsonr 

from scipy.stats import invgamma 
from scipy.stats import beta
import matplotlib.pyplot as plt

import plotly
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)

from IPython.display import clear_output

from Euc_pca_tools.Input_tools import read_Darwin, read_refs
from Euc_pca_tools.Euc_to_fst import Euc_to_fst
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
whil

# %% [markdown]
# ## I. Load data.
#
# The simulations performed in this post will be adjusted to the sequence length of the DataMatrix provided. We extracted SNP variation at a number of loci and stored it in DataMatrix format (Darwin software).
#
# We first load and organise our data. All the information available is in the DataMatrix file, which is useful.

# %%
## load real data

DM_filename= 'Dmatrices/RC_DataMatrix.txt'
DM_filename= 'Dmatrices/qSH1_DataMatrix.txt'
DM_filename= 'Dmatrices/random1_DataMatrix.txt'
#DM_filename= 'Dmatrices/bh4_DataMatrix.txt'
#DM_filename= 'Dmatrices/Waxy_DataMatrix.txt'
#DM_filename= 'Dmatrices/SH4_DataMatrix.txt'
#DM_filename= 'Dmatrices/Osc1_DataMatrix.txt'
#DM_filename= 'Dmatrices/Jtrop_ind3_chrom11_DataMatrix.txt'
DM_filename= 'Dmatrices/coord_test_DataMatrix.txt'
data, Names= read_Darwin(DM_filename)
gen_data= np.array(data)

ref_file= 'Complementary_data/refs_CORE.txt' # columns: ID; code. code as preferably as integer.

if ref_file:
    ## read accession data
    ref_lib, codes= read_refs(ref_file)
    ref_names= [z for z in it.chain(*[ref_lib[r] for r in ref_lib.keys()])]
    ref_codes= np.repeat(list(ref_lib.keys()),[len(ref_lib[x]) for x in ref_lib.keys()])

    present= [x for x in range(gen_data.shape[0]) if Names[x] in ref_names] # In case some names are missing from the ref file.

    color_code= [ref_codes[ref_names.index(Names[x])] for x in present]
    color_indexes= {z:[present[x] for x in range(len(color_code)) if color_code[x] == z] for z in list(set(color_code))}
    
    ##
    colors= {
        0:[192,192,192],
        1: [255,0,0],
        2: [0,128,0],
        3: [255,255,0],
        4: [0,0,255],
        5: [255,255,255],
    }
    
    colors= {
        z: 'rgba({},.8)'.format(','.join([str(x) for x in colors[z]])) for z in colors.keys()
    }
    
    ## Currently reference codes are integers. in
    
    ref_names= ['blanc','Indica','black','cAus','Japonica','control']
    

print(gen_data.shape)
# Out:
# (779, 72)

# %% [markdown]
# ##  III. Simulations.
#
#
# The next function generates a number of data sets with a varying number of populations at varying genetic distances. For each data set euclidian distances are calculated in feature space between the centroids of the populations generated.
#
# In Summary, for each iteration, the next blocks will:
# - select population vectors from the base data set created in **I.**.
# - calculate pairwise Fsts between the selected vectors.
# - Generate a varying number of samples from each of the vectors selected.
# - perform PCA on each of the generated data sets.
# - Calculate pairwise centroid distances between the PCA projections of different haploid populations produced.
#
# First a background data set of population frequency vectors of the appropriate length is generated.
#
# - visit notebook [1 Generate Samples](https://nbviewer.jupyter.org/github/SantosJGND/Genetic-data-analysis/blob/master/Notebooks/1.%20Generating_haplotypes.ipynb) ([Stats Lab](https://github.com/SantosJGND/Stats_Lab)) for more details on the background data set.

# %%
Nbranches= 4 # number of axes
L= gen_data.shape[1] # number of markers.
n= 100 # number of frequency vectors.
n_comp_haps= 5
rangeA= [1,2.5] # range along which to vary parameter a of beta dist.
rangeB = [.1,.6] # range along which to vary parameter b of beta dist.
steps= 20 # number of steps along ranges of parameters and b.
n_comp = L # number of components to retain in PCA of frequency vectors (>>).
density= 50 # number of populations along each branch.

from Euc_pca_tools.Generate_freq_vectors import generate_Branches_Beta

features, vector_lib= generate_Branches_Beta(4,50,L,n,rangeA,rangeB,steps,n_comp)

print(features.shape)
print(vector_lib.shape)
# Out:
# (200, 72)
# (200, 72)

# %%
m_coeff, b, Distances, fst_x, y_true= Euc_to_fst(vector_lib,n_comp= n_comp_haps,ploidy= 2)
# Out:
# Iter: 0, vectors selected: [151 142 184 132  72], hap length: 72
# C:\Users\jgarcia\Desktop\Jupyter_stuff\Tools_and_toys\PCA_Fst_estimation\Euc_pca_tools\StructE_tools.py:398: RuntimeWarning:
#
# invalid value encountered in double_scalars
# Iter: 1, vectors selected: [ 5 93 32], hap length: 72
# Iter: 2, vectors selected: [173  27  30 189], hap length: 72
# Iter: 3, vectors selected: [ 21 111 194 100  78], hap length: 72
# Iter: 4, vectors selected: [ 28  16  59 154 172  22], hap length: 72
# Iter: 5, vectors selected: [147  70   3 158  14  21], hap length: 72
# Iter: 6, vectors selected: [100  71 145], hap length: 72
# Iter: 7, vectors selected: [104  20  44 118 159 117 143], hap length: 72
# Iter: 8, vectors selected: [168  94 104 143  88], hap length: 72
# Iter: 9, vectors selected: [181 152 166  53 182  95  85], hap length: 72
# Iter: 10, vectors selected: [149 182 185], hap length: 72
# Iter: 11, vectors selected: [160  65  71 145], hap length: 72
# Iter: 12, vectors selected: [127 108   0 198 154], hap length: 72
# Iter: 13, vectors selected: [ 25 192 119], hap length: 72
# Iter: 14, vectors selected: [ 87 148  10  51], hap length: 72
# Iter: 15, vectors selected: [167 175 126   2  99], hap length: 72
# Iter: 16, vectors selected: [ 29 191  98 118 175 167], hap length: 72
# Iter: 17, vectors selected: [173   3  40  51 111], hap length: 72
# Iter: 18, vectors selected: [ 90 115  71 127  64  40], hap length: 72
# Iter: 19, vectors selected: [ 18  59  67 188], hap length: 72

# %% [markdown]
# ## IV. Data analysis
#
#
# We will first confirm that our prediction of genetic distances from PCA euclidian distances is reasonable.

# %%
from plotly import tools
from Euc_pca_tools.plot_tools import plot_fst

plot_fst(fst_x,y_true)
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]
# <div id="4398421b-ed2c-4fb9-a255-5806ac92d10d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("4398421b-ed2c-4fb9-a255-5806ac92d10d", [{"mode": "markers", "uid": "7e230adc-1fe0-4b5c-aa8e-af4b5d39b9a6", "x": [0.2772324981347433, 0.1981343432747542, 0.21078015679759618, 0.2256191420639726, 0.029277036542956797, 0.06526775634258421, 0.18815256214503107, 0.023893840348646733, 0.1391115476620375, 0.1360333137563984, 0.26070080162476206, 0.15267798146520753, 0.04992555164000397, 0.08503426869740112, 0.0808914623604894, 0.13222577789793138, 0.006992089100782523, 0.08555977710907237, 0.05071541239888615, 0.23258921238492825, 0.1925662996137507, 0.27814217476437914, 0.150938621605585, 0.2973717720086757, 0.01761531137887203, 0.23039383464673213, 0.09574849199776149, 0.2869082954897419, 0.05969477532680086, 0.21037359740358771, 0.1723509391853281, 0.08913850378229167, 0.027345449624914604, 0.2738565830596372, 0.1931393341974172, 0.1486374513024937, 0.013829224271641764, 0.232671615968671, 0.18258492766826095, 0.23708509648657897, 0.048336527898421265, 0.1732735687378161, 0.11678050308643084, 0.21923233333639142, 0.2874653051907828, 0.2637460953805908, 0.2369792979523247, 0.18816623614793032, 0.2933349407604004, 0.20854056770697066, 0.2462969865556056, 0.20513607286929517, 0.22713452305517792, 0.013799768184980146, 0.04139008670469863, 0.19186862235753943, 0.16753310065298463, 0.013905621279156618, 0.2065237889237814, 0.26759904462961387, 0.036024089406384026, 0.27255633411507707, 0.03139977284269244, 0.2255418269811865, 0.20494104495166993, 0.16820822879871714, 0.2096724533065816, 0.1854230741505434, 0.2469157572919477, 0.26862795063001255, 0.2546728979084185, 0.02079611825324068, 0.2191055104835787, 0.0005644997023683764, 0.27600925605790344, 0.22249000152974482, 0.24658553003014191, 0.28387047430668044, 0.19001312710003457, 0.25478723125243313, 0.18705660953172862, 0.16075572595643065, 0.020172765028295486, 0.016070818151007363, 0.016307789325477395, 0.14938517911416377, 0.08472834540988788, 0.20869823829208098, 0.0006237953980862963, 0.06463697120836602, 0.021997934304385312, 0.023663749227445317, 0.2472557090555022, 0.163298901839403, 0.2838116200001013, 0.228002350506051, 0.21281069793827434, 0.0965438628858553, 0.2096888306879608, 0.1548102220689681, 0.21262135504875368, 0.20928056777502513, 0.05699606411541519, 0.016521283439886996, 0.045156806603949065, 0.06753903732490357, 0.047304913913820155, 0.0067574181167022115, 0.21176922608865512, 0.1984748490502629, 0.24867529040444195, 0.008267671794699255, 0.23903629230796758, 0.2065237889237814, 0.09774667274256245, 0.23064692459005282, 0.13833718098822978, 0.19603318374164366, 0.2950632801519203, 0.26774692267487477, 0.2417606125881694, 0.13538812649898013, 0.17696369227063316, 0.23099098498106005, 0.034947250256616234, 0.2141964576251043, 0.2585406074702601, 0.2549841727859341, 0.024739142000757355, 0.14516303869021635, 0.21014189138037137, 0.21488169728549905, 0.09829458896781545, 0.2010342831546041, 0.14049043888682103, 0.2262127484320522, 0.17496769420596553, 0.28662162913700573, 0.0735608715113613, 0.09587626103432155, 0.1766931543923859, 0.06382816949663277, 0.11638666118587647, 0.03254252009759632, 0.23579394037312684, 0.12086369922404162, 0.20142082530865885, 0.26998057120268604, 0.13663127129382158, 0.2116643537866964, 0.16767311631966578, 0.1913724835449832, 0.024739142000757355, 0.19758274670820133, 0.1353569755867587, 0.20511150383356094, 0.21005297552764457, 0.2862679370440922, 0.27785897923681685, 0.26805986554685174, 0.28259740630332036, 0.27785064598629217, 0.2557341592449099, 0.2093721758469389, 0.11612063156411487, 0.2490794980342389, 0.00858575873484407, 0.22620859454356002, 0.05844077269861984, 0.23741095298510423, 0.252415481478842, 0.15253700235623385, 0.010229716931199612, 0 ...

# %% [markdown]
# **Fig. True and predicted Fsts.**

# %% [markdown]
# ### Fst and euclidian genetic distances

# %% [markdown]
# ## Real data
#
# In this section we apply the relation learned during the preceding simulation step to the study of genetic structure at the chosen locus.
#
# i. We will first perform PCA on the data matrix loaded, together with haplotypes from the two control populations. The data matrix came with labels and individual IDs. These are displayed in the first graph.
#
# ii. We then perform Mean Shift unsupervised clustering to the real data in feature space. MeanShift is a clustering algorithm that relies on the KDE estimate of observed data to identify peaks, to which it assigns observations based on proximity ( ** ). The output of this clusterisation is displayed on the second graph.
#
# iii. For the third part the user is first asked to chose a set of MeanShift clusters. The pairwise distances between the centroids of the chosen clusters will be calculated and their respective Fsts inferred from the relation shown in the above plot. The clusters chosen and the vectors connecting are plotted, annotated with their respective distances.

# %%
### Build control data set with apropriate distances.
from Euc_pca_tools.plot_tools import plot_3D
diploid= True

length_haps= gen_data.shape[1]

## Perform PCA with or without including control populations.
gen_data= np.nan_to_num(gen_data)

pca = PCA(n_components=5, whiten=False,svd_solver='randomized').fit(gen_data)
feats= pca.transform(gen_data)
var_comps= pca.explained_variance_ratio_

if ref_file:
     
    plot_3D(feats,color_indexes,colors= colors,Names=Names,var_comps= var_comps,ref_names= ref_names)
# Out:
# c:\users\jgarcia\appdata\local\programs\python\python36-32\lib\site-packages\plotly\graph_objs\_deprecations.py:477: DeprecationWarning:
#
# plotly.graph_objs.Scene is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.Scene
# <div id="58aa4916-f2f2-4ebb-a847-225525bee2e4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("58aa4916-f2f2-4ebb-a847-225525bee2e4", [{"marker": {"color": "rgba(255,0,0,.8)", "line": {"width": 0}, "opacity": 1, "size": 4, "symbol": "circle"}, "mode": "markers", "name": "Indica", "text": ["ID: IRIS_313-9121, gp: Indica", "ID: IRIS_313-11162, gp: Indica", "ID: B010, gp: Indica", "ID: IRIS_313-9182, gp: Indica", "ID: IRIS_313-10990, gp: Indica", "ID: B026, gp: Indica", "ID: B029, gp: Indica", "ID: IRIS_313-10511, gp: Indica", "ID: IRIS_313-11205, gp: Indica", "ID: IRIS_313-9262, gp: Indica", "ID: IRIS_313-8660, gp: Indica", "ID: B059, gp: Indica", "ID: B061, gp: Indica", "ID: IRIS_313-9317, gp: Indica", "ID: IRIS_313-9320, gp: Indica", "ID: IRIS_313-9324, gp: Indica", "ID: IRIS_313-9325, gp: Indica", "ID: IRIS_313-10997, gp: Indica", "ID: IRIS_313-10614, gp: Indica", "ID: B073, gp: Indica", "ID: IRIS_313-11234, gp: Indica", "ID: B076, gp: Indica", "ID: B079, gp: Indica", "ID: B081, gp: Indica", "ID: IRIS_313-9384, gp: Indica", "ID: B089, gp: Indica", "ID: B090, gp: Indica", "ID: B091, gp: Indica", "ID: B092, gp: Indica", "ID: B094, gp: Indica", "ID: B095, gp: Indica", "ID: B096, gp: Indica", "ID: B097, gp: Indica", "ID: IRIS_313-11256, gp: Indica", "ID: IRIS_313-9424, gp: Indica", "ID: IRIS_313-9427, gp: Indica", "ID: IRIS_313-11261, gp: Indica", "ID: IRIS_313-11262, gp: Indica", "ID: B107, gp: Indica", "ID: IRIS_313-11264, gp: Indica", "ID: IRIS_313-11266, gp: Indica", "ID: IRIS_313-11267, gp: Indica", "ID: B113, gp: Indica", "ID: B115, gp: Indica", "ID: B116, gp: Indica", "ID: IRIS_313-11273, gp: Indica", "ID: IRIS_313-11275, gp: Indica", "ID: IRIS_313-11276, gp: Indica", "ID: B121, gp: Indica", "ID: IRIS_313-9492, gp: Indica", "ID: B123, gp: Indica", "ID: IRIS_313-11280, gp: Indica", "ID: B125, gp: Indica", "ID: IRIS_313-11282, gp: Indica", "ID: IRIS_313-11283, gp: Indica", "ID: IRIS_313-11284, gp: Indica", "ID: B129, gp: Indica", "ID: B130, gp: Indica", "ID: B131, gp: Indica", "ID: IRIS_313-11288, gp: Indica", "ID: IRIS_313-11292, gp: Indica", "ID: IRIS_313-11294, gp: Indica", "ID: IRIS_313-9560, gp: Indica", "ID: B140, gp: Indica", "ID: IRIS_313-9570, gp: Indica", "ID: IRIS_313-11300, gp: Indica", "ID: IRIS_313-11301, gp: Indica", "ID: IRIS_313-11303, gp: Indica", "ID: IRIS_313-9590, gp: Indica", "ID: B149, gp: Indica", "ID: IRIS_313-9594, gp: Indica", "ID: IRIS_313-11307, gp: Indica", "ID: IRIS_313-11308, gp: Indica", "ID: IRIS_313-11309, gp: Indica", "ID: IRIS_313-11310, gp: Indica", "ID: IRIS_313-9605, gp: Indica", "ID: B157, gp: Indica", "ID: IRIS_313-11316, gp: Indica", "ID: IRIS_313-9619, gp: Indica", "ID: B163, gp: Indica", "ID: IRIS_313-11321, gp: Indica", "ID: IRIS_313-9634, gp: Indica", "ID: IRIS_313-11338, gp: Indica", "ID: IRIS_313-11345, gp: Indica", "ID: IRIS_313-11346, gp: Indica", "ID: IRIS_313-11347, gp: Indica", "ID: B197, gp: Indica", "ID: IRIS_313-10814, gp: Indica", "ID: B208, gp: Indica", "ID: B210, gp: Indica", "ID: B214, gp: Indica", "ID: B216, gp: Indica", "ID: B217, gp: Indica", "ID: B222, gp: Indica", "ID: IRIS_313-10847, gp: Indica", "ID: IRIS_313-11306, gp: Indica", "ID: B229, gp: Indica", "ID: IRIS_313-11382, gp: Indica", "ID: IRIS_313-11383, gp: Indica", "ID: IRIS_313-11386, gp: Indica", "ID: IRIS_313-9867, gp: Indica", "ID: B247, gp: Indica", "ID: B249, gp: Indica", "ID: B252, gp: Indica", "ID: B253, gp: Indica", "ID: B254, gp: Indica", "ID: B259, gp: Indica", "ID: IRIS_313-11407, gp: Indica", "ID: B264, gp: Indica", "ID: B265, gp: Indica", "ID: IRIS_313-9968, gp: Indica", "ID: IRIS_313-9969, gp: Indica", "ID: IRIS_313-11206, gp: Indica", "ID: IRIS_313-9976, gp: Indica", "ID: IRIS_313-10674, gp: Indica", "ID: IRIS_313-11442, gp: Indica", "ID: IRIS_313-10675, gp: Indica", "ID: IRIS_313-11447, gp: Indica", "I ...

# %% [markdown]
# **Fig. Genetic structure** at locus of choice.

# %%
#### MeanShift clusters

N= 50
bandwidth = estimate_bandwidth(feats, quantile=0.15)
params = {'bandwidth': np.linspace(np.min(feats), np.max(feats),20)}
grid = GridSearchCV(KernelDensity(algorithm = "ball_tree",breadth_first = False), params,verbose=0)

## perform MeanShift clustering.
ms = MeanShift(bandwidth=bandwidth, bin_seeding=False, cluster_all=True, min_bin_freq=25)
ms.fit(feats[present,:])
labels1 = ms.labels_
label_select = {y:[present[x] for x in range(len(labels1)) if labels1[x] == y] for y in sorted(list(set(labels1))) if y != -1}

iu_control= np.triu_indices(len(label_select),1)
MS_centroids= [np.mean(feats[label_select[z],:],axis= 0) for z in label_select.keys()]
MS_pair_dist= pairwise_distances(MS_centroids,metric= 'euclidean')
MS_pair_dist= MS_pair_dist[iu_control]

plot_3D(feats,label_select,Names=Names,var_comps= var_comps)
# Out:
# c:\users\jgarcia\appdata\local\programs\python\python36-32\lib\site-packages\plotly\graph_objs\_deprecations.py:477: DeprecationWarning:
#
# plotly.graph_objs.Scene is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.Scene
# <div id="d66712eb-fe26-4a18-b81c-24bd08b2a572" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d66712eb-fe26-4a18-b81c-24bd08b2a572", [{"marker": {"color": 0, "line": {"width": 0}, "opacity": 1, "size": 4, "symbol": "circle"}, "mode": "markers", "name": "0", "text": ["ID: IRIS_313-9121, gp: 0", "ID: IRIS_313-11162, gp: 0", "ID: B026, gp: 0", "ID: B029, gp: 0", "ID: IRIS_313-10511, gp: 0", "ID: IRIS_313-9262, gp: 0", "ID: IRIS_313-8660, gp: 0", "ID: IRIS_313-9317, gp: 0", "ID: IRIS_313-9320, gp: 0", "ID: IRIS_313-9324, gp: 0", "ID: IRIS_313-9325, gp: 0", "ID: IRIS_313-10997, gp: 0", "ID: B073, gp: 0", "ID: IRIS_313-11234, gp: 0", "ID: B076, gp: 0", "ID: B081, gp: 0", "ID: B089, gp: 0", "ID: B096, gp: 0", "ID: IRIS_313-9424, gp: 0", "ID: IRIS_313-9427, gp: 0", "ID: IRIS_313-11261, gp: 0", "ID: IRIS_313-11262, gp: 0", "ID: B107, gp: 0", "ID: IRIS_313-11266, gp: 0", "ID: B113, gp: 0", "ID: B115, gp: 0", "ID: B116, gp: 0", "ID: IRIS_313-11276, gp: 0", "ID: IRIS_313-11280, gp: 0", "ID: B125, gp: 0", "ID: IRIS_313-11283, gp: 0", "ID: IRIS_313-11284, gp: 0", "ID: B129, gp: 0", "ID: B130, gp: 0", "ID: B131, gp: 0", "ID: IRIS_313-9560, gp: 0", "ID: IRIS_313-9570, gp: 0", "ID: IRIS_313-9590, gp: 0", "ID: IRIS_313-11307, gp: 0", "ID: IRIS_313-11308, gp: 0", "ID: IRIS_313-11309, gp: 0", "ID: IRIS_313-11310, gp: 0", "ID: IRIS_313-9605, gp: 0", "ID: IRIS_313-11316, gp: 0", "ID: IRIS_313-9619, gp: 0", "ID: IRIS_313-11321, gp: 0", "ID: IRIS_313-11346, gp: 0", "ID: B197, gp: 0", "ID: IRIS_313-10814, gp: 0", "ID: B214, gp: 0", "ID: B216, gp: 0", "ID: B217, gp: 0", "ID: IRIS_313-10847, gp: 0", "ID: B229, gp: 0", "ID: IRIS_313-11386, gp: 0", "ID: IRIS_313-9867, gp: 0", "ID: B253, gp: 0", "ID: B254, gp: 0", "ID: IRIS_313-11407, gp: 0", "ID: B265, gp: 0", "ID: IRIS_313-9968, gp: 0", "ID: IRIS_313-9969, gp: 0", "ID: IRIS_313-9976, gp: 0", "ID: IRIS_313-10674, gp: 0", "ID: IRIS_313-11442, gp: 0", "ID: IRIS_313-11447, gp: 0", "ID: IRIS_313-11461, gp: 0", "ID: IRIS_313-11472, gp: 0", "ID: IRIS_313-10681, gp: 0", "ID: IRIS_313-11521, gp: 0", "ID: IRIS_313-10687, gp: 0", "ID: IRIS_313-10171, gp: 0", "ID: IRIS_313-10177, gp: 0", "ID: IRIS_313-10179, gp: 0", "ID: IRIS_313-11530, gp: 0", "ID: IRIS_313-10221, gp: 0", "ID: B064, gp: 0", "ID: IRIS_313-11565, gp: 0", "ID: CX141, gp: 0", "ID: CX148, gp: 0", "ID: CX150, gp: 0", "ID: CX154, gp: 0", "ID: CX158, gp: 0", "ID: IRIS_313-11443, gp: 0", "ID: IRIS_313-11635, gp: 0", "ID: IRIS_313-11638, gp: 0", "ID: IRIS_313-11642, gp: 0", "ID: IRIS_313-11646, gp: 0", "ID: IRIS_313-11648, gp: 0", "ID: IRIS_313-10706, gp: 0", "ID: IRIS_313-10477, gp: 0", "ID: IRIS_313-11824, gp: 0", "ID: IRIS_313-11664, gp: 0", "ID: IRIS_313-11666, gp: 0", "ID: IRIS_313-11667, gp: 0", "ID: IRIS_313-11668, gp: 0", "ID: IRIS_313-11674, gp: 0", "ID: IRIS_313-10518, gp: 0", "ID: IRIS_313-11679, gp: 0", "ID: IRIS_313-11681, gp: 0", "ID: IRIS_313-11683, gp: 0", "ID: IRIS_313-11684, gp: 0", "ID: IRIS_313-11685, gp: 0", "ID: IRIS_313-11686, gp: 0", "ID: IRIS_313-11687, gp: 0", "ID: IRIS_313-11693, gp: 0", "ID: IRIS_313-11700, gp: 0", "ID: IRIS_313-11704, gp: 0", "ID: IRIS_313-11705, gp: 0", "ID: IRIS_313-11706, gp: 0", "ID: IRIS_313-11707, gp: 0", "ID: IRIS_313-11708, gp: 0", "ID: IRIS_313-11709, gp: 0", "ID: IRIS_313-11710, gp: 0", "ID: IRIS_313-11711, gp: 0", "ID: IRIS_313-10824, gp: 0", "ID: IRIS_313-11717, gp: 0", "ID: IRIS_313-11719, gp: 0", "ID: IRIS_313-11728, gp: 0", "ID: IRIS_313-11730, gp: 0", "ID: IRIS_313-11731, gp: 0", "ID: IRIS_313-11732, gp: 0", "ID: IRIS_313-11733, gp: 0", "ID: IRIS_313-11734, gp: 0", "ID: IRIS_313-11744, gp: 0", "ID: IRIS_313-11745, gp: 0", "ID: IRIS_313-11746, gp: 0", "ID: IRIS_313-11747, gp: 0", "ID: IRIS_313-11748, gp: 0", "ID: IRIS_313-9406, gp: 0", "ID: IRIS_313-11076, gp: 0", "ID: IRIS_313-9409, gp: 0", "ID: IRIS_313-10651, ...

# %% [markdown]
# **Fig. Mean Shift clustering of PCA projections** of real data at locus of choice.
#
# Identify accessions at MS cluster of choice.

# %% [markdown]
# At the top of the next block, select the clusters between which to calculate distances.

# %%
from Euc_pca_tools.plot_tools import plot_vertix
#### Making it interesting:
Vertices= [0,1,2,4]

plot_vertix(feats,label_select,Vertices,m_coeff= m_coeff,b= b, color= '#1f77b4')
# Out:
# c:\users\jgarcia\appdata\local\programs\python\python36-32\lib\site-packages\plotly\graph_objs\_deprecations.py:477: DeprecationWarning:
#
# plotly.graph_objs.Scene is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.Scene
# <div id="437d76ed-3bde-480f-b506-600a50d1fc33" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("437d76ed-3bde-480f-b506-600a50d1fc33", [{"line": {"color": 0, "width": 2}, "marker": {"color": "#1f77b4", "size": 5}, "name": "pred Fst (0, 1): 0.16", "text": ["group: 0", "group: 1"], "x": [-3.3853985309738555, 0.5241549794065153], "y": [-0.826419331172294, 3.486335510093826], "z": [-0.33961963003610784, 0.1220314613960142], "type": "scatter3d", "uid": "231bfa89-0260-4478-a5dc-717ef219abe4"}, {"line": {"color": 1, "width": 2}, "marker": {"color": "#1f77b4", "size": 5}, "name": "pred Fst (0, 2): 0.19", "text": ["group: 0", "group: 2"], "x": [-3.3853985309738555, 2.93149867890339], "y": [-0.826419331172294, -2.507961403010525], "z": [-0.33961963003610784, -0.38628826030207847], "type": "scatter3d", "uid": "ea411eba-a9f9-4171-ae7c-ee485b89eae2"}, {"line": {"color": 2, "width": 2}, "marker": {"color": "#1f77b4", "size": 5}, "name": "pred Fst (0, 4): 0.21", "text": ["group: 0", "group: 4"], "x": [-3.3853985309738555, 1.3673919038984166], "y": [-0.826419331172294, -0.816185132103072], "z": [-0.33961963003610784, 4.842354645410063], "type": "scatter3d", "uid": "95b2978a-b26d-4d5a-918e-cfc0842cc21d"}, {"line": {"color": 3, "width": 2}, "marker": {"color": "#1f77b4", "size": 5}, "name": "pred Fst (1, 2): 0.18", "text": ["group: 1", "group: 2"], "x": [0.5241549794065153, 2.93149867890339], "y": [3.486335510093826, -2.507961403010525], "z": [0.1220314613960142, -0.38628826030207847], "type": "scatter3d", "uid": "afa4a809-e5e3-4f03-b868-dfcafce967ab"}, {"line": {"color": 4, "width": 2}, "marker": {"color": "#1f77b4", "size": 5}, "name": "pred Fst (1, 4): 0.2", "text": ["group: 1", "group: 4"], "x": [0.5241549794065153, 1.3673919038984166], "y": [3.486335510093826, -0.816185132103072], "z": [0.1220314613960142, 4.842354645410063], "type": "scatter3d", "uid": "371c52dc-83ad-43d8-954e-19c3bbe1edc0"}, {"line": {"color": 5, "width": 2}, "marker": {"color": "#1f77b4", "size": 5}, "name": "pred Fst (2, 4): 0.18", "text": ["group: 2", "group: 4"], "x": [2.93149867890339, 1.3673919038984166], "y": [-2.507961403010525, -0.816185132103072], "z": [-0.38628826030207847, 4.842354645410063], "type": "scatter3d", "uid": "fb7c8c3c-eb69-4c68-a303-acc840ecd889"}, {"marker": {"color": "#1f77b4", "size": 5}, "mode": "markers", "name": "Cl: 0", "x": [-3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -2.114438429683851, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -2.1243839082170957, -3.421011717316537, -3.421011717316537, -3.428330759266972, -3.421011717316537, -2.1197187687155195, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -2.11772270171263, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.423447923225928, -3.421011717316537, -3.421011717316537, -2.7751397905992503, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -2.770474651097673, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.421011717316537, -3.4210117173165 ...

# %% [markdown]
# **Fig. Genetic structure summary** Genetic distances between clusters selected are represented as edges.
